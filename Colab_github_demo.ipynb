# %% [markdown]
# <a href="https://colab.research.google.com/github/iramos02/bio108tutorial/blob/main/Colab_github_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scraping data: Programmatic data access in Python
#
# ### Learning Objectives
#
# After completing this tutorial, you will be able to:
#
# * Describe the difference between human and machine readable data structures.
# * Describe the difference between data returned using an API compared to downloading a text file directly.
# * Describe 2-3 components of a RESTful API call.
# * List different ways to access data programmatically in Python.
#
# ## Access Data Programmatically
#
# This week, you will learn how to programmatically access data using:
#
# 1. Direct downloads / import of data.
# 2. Applied Programming Interfaces (APIs).
#
# Up until this point, you have been interacting with pre-downloaded data or data that is easily accessible via a URL. Then, you work with the data in `Python` using packages such as `Pandas`.
#
# However, independently downloading and unzipping data each week is not scalable -- what if you wanted to dynamically analyze occurrence patterns for species week by week?
#
# You can automate the data download process using `Python`. Automation is particularly useful when:
#
# * You want to download lots of data or particular subsets of data to support an analysis.
# * There are programmatic ways to access and query the data online.
#
# ### Link Data Access to Processing & Analysis
#
# When you automate data access, download, or retrieval, and embed it in your code, you are **directly** linking your analysis to your data. Further, combined with  Jupyter Notebooks, code comments and expressive coding techniques, you are better documenting your workflow.
#
# In short - by linking data access and download to your analysis - you are not only reminding your future selves of your process - you are also reminding your future self where (and how) you got the data in the first place! Similarly, this allows your workflow to be easily reproduced by others.
#
# ## Three Ways to Access Data
#
# You can break up programmatic data access into three general categories:
#
# 1. Data that you download by calling a specific URL and using the `Pandas` function `read_csv`, which takes in a url.
# 2. Data that you directly import into `Python` using the `Pandas` function `read_csv`.
# 3. Data that you download using an API, which makes a **request** to a data repository and **returns** requested data.
#
# ### Two Key Formats
#
# The data that you access programmatically may be returned in one of two main formats:
#
# 1. **Tabular Human-readable file:** Files that are tabular, including CSV files (Comma Separated Values) and even spreadsheets (Microsoft Excel, etc.). These files are organized into columns and rows and are "flat" in structure rather than hierarchical.
# 2. **Structured Machine-readable files:** Files that can be stored in a text format but are hierarchical and structured in some way that optimizes machine readability. JSON files ([FMI here](https://stackoverflow.blog/2022/06/02/a-beginners-guide-to-json-the-data-format-for-the-internet/)) are an example of structured machine-readable files.
#
# **Data Tip:** There are non-text formatted hierarchical data structures that you will not learn in this course. One example of this is the HDF5 data model (structure). Another is Parquet.
#
# ### Download Files Programmatically
#
# ####  `Pandas` function `read_csv()`
#
# Note that you can use the `read_csv()` function from `Pandas` to import data directly into `Python` by providing a URL to the CSV file (e.g. `read_csv(URL)`).
#
# When you programmatically read data into `Python` using `read_csv()` you are not saving a copy of your data locally, on your computer - you are importing the data directly into `Python`.
#
# If you want a copy of that data to use for future analysis without directly importing it, you will need to export the data to your working directory using `write_csv()`.
#
# Below is an example of directly importing data into `Python` using `read_csv()`. The data are average annual temperature in Canada from the World Bank.
#
#
# ```python
# import matplotlib.pyplot as plt
# import pandas as pd
# ```
#
# ```python
# url = "http://climatedataapi.worldbank.org/climateweb/rest/v1/country/cru/tas/year/CAN.csv"
# df = pd.read_csv(url)
#
# df.head()
# ```

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #### Human Readable Data
#
# Notice that the data that you downloaded above using are **tabular** and thus **human-readable**. The data are organized into a tabular structure with rows and columns that you can quickly understand. `Python` can import these data into a `Pandas DataFrame` and you can work with it programmatically.
#
# However, what happens if your data structure is more complex? For example, what if you wanted to store more information about each measured precipitation data point? Your table could get very wide very quickly making is less readable but also more computationally intensive to process.
#
# You will learn about structured machine readable data structures later in this module, which may be hard for humans to quickly digest when you look at them but are much more efficient to process - particular as your data get large.
#
# ## A deeper dive in JSON data
#
# Learning Objectives
#
# After completing this tutorial, you will be able to:
#
# * Describe the key structure elements of a `JSON` data structure: name/value pairs.
# * Identify the components of the hierarchical `JSON` data structures including: objects, arrays and data elements.
# * List some of the core data types that a `JSON` data structure can store including: boolean, numeric and string.
#
# In this lesson, you will explore the **machine readable** JSON data structure. Machine readable data structures are more efficient - particularly for larger data that contain hierarchical structures.
#
# ## About JSON
#
# Before going any further, let's take a look at the **J**ava**S**cript
# **O**bject **N**otation or **JSON** data structure. JSON is a common format for larger data that have a hierarchical structured relationship.
#
# In `Python`, `JSON` data is similar to a dictonary because it has keys (i.e. names) and values, but it is encoded as a string.
#
# The `Python` library `json` is helpful to convert data from lists or dictonaries into `JSON` strings and `JSON` strings into lists or dictonaries. `Pandas` can also be used to convert `JSON` data (via a `Python` dictionary) into a `Pandas` `DataFrame`.
#
# The structure of a `JSON` object is as follows:
#
# * The data are in name/value pairs using colons `:`.
# * Data **objects** are separated by commas.
# * Curly braces `{}` hold the objects.
# * Square brackets `[]` can be used to indicate an **array** that contains a group of objects.
# * Each **data element** is enclosed with quotes `""` if it is a character, or without quotes if it is a numeric value.
#
# Example of a name/value pair using a colon:
# ```json
#  { "name":"Chaya" }
# ```
#
# Example of objects separated by commas:
# ```json
# { "name":"Chaya", "age":12, "city":"Boulder", "type":"Canine" }
# ```
#
# Notice that the data above are structured. Thus, each element contains a particular object name (name, age, city, etc) and values are associated with these names. This is similar to column headings in a CSV file.
#
# However, the `JSON` structure can also be nested using square brackets to indicate an array that contains a group of objects, like this:
#
# ```json
# {"students":[
#     { "firstName":"Serena", "lastName":"Williams" },
#     { "firstName":"Boe", "lastName":"Diddly" },
#     { "firstName":"Al", "lastName":"Gore" }
# ]}
# ```
#
# The ability to store nested or **hierarchical** data within a text file structure makes `JSON` a powerful format to use as you are working with larger datasets.
#
# **Data Tip:** The GeoJSON data structure is a powerful data structure that supports spatial data. GeoJSON can be used to create maps just like shapefiles can. This format is often used for web mapping applications like Leaflet (or Leafmap!).
#
#
# ### JSON Data Structures
#
# `JSON` can store any of the following data types:
#
# * strings
# * numbers
# * objects (`JSON` object)
# * arrays
# * booleans (TRUE / FALSE)
# * null
#
# Note that in the example below, the word "Chaya", which is the value associated with "name", is in quotes `""`. This specifies that "Chaya" is a string (characters rather than numeric).
#
# ```json
#  { "name":"Chaya" }
# ```
#
# In this example, the value 12, associated with "age", is not in quotes. This specifies that this value is a number or of type `numeric`.
#
# ```json
# { "name":"Chaya", "age":12, "city":"Boulder", "type":"Canine" }
# ```
# In the next lesson, you will work with JSON structured data, returned from an automated Python query online. Below is an example of a data snippet that could be returned from some online source in a JSON format. Notice that the `JSON` is enclosed in brackets `[]` to indicate an array containing a group of objects.
#
# ```json
# [{"age":"0","county":"Adams","datatype":"Estimate","femalepopulation":"2404","fipscode":"1","malepopulation":"2354","totalpopulation":"4758","year":"1990"}
# ,{"age":"1","county":"Adams","datatype":"Estimate","femalepopulation":"2375","fipscode":"1","malepopulation":"2345","totalpopulation":"4720","year":"1990"}
# ,{"age":"2","county":"Adams","datatype":"Estimate","femalepopulation":"2219","fipscode":"1","malepopulation":"2413","totalpopulation":"4632","year":"1990"}]
# ```

# %% [markdown]
# ## What is an API?
#
# An API (Application Programming Interface) is an interface that sits on top of a
# computer based system and simplifies certain tasks, such as extracting subsets
# of data from a large repository or database.
#
# ### Using Web-APIs
#
# Web APIs allow you to access data available via an internet web interface.
#
# Often you can access data from web APIs using a URL that contains sets of parameters
# that specifies the type and particular subset of data that you are interested in.
#
# If you have worked with a database such as `Microsoft SQL Server` or `PostgreSQL`, or if you've ever queried data from a GIS system like ArcGIS, then you can compare the set of parameters associated with a URL string to a SQL query.
#
# > Web APIs are a way to strip away all the extraneous visual interface that
# > you don't care about and get the data that you want.
#
# ### Why You Use Web APIs
#
# Among other things, APIs allow us to:
#
# * Get information that would be time-consuming to get otherwise.
# * Get information that you can't get otherwise.
# * Automate an analytical workflows that require continuously updated data.
# * Access data using a more direct interface.
#
# ### Three Parts of an API Request
#
# When we talk about APIs, it is important to understand two key components: the request and the response. The third part listed below is the intermediate step where the request is PROCESSED by the remote server.
#
# 1. Data **REQUEST**: You try to access a `URL` in your browser that specifies a particular subset of data.
# 2. **Data processing:** A web server somewhere uses that url to query a specified dataset.
# 3. Data **RESPONSE**: That web server then sends you back some content.
#
# The **response** may give you one of two things:
# 1. Some *data* or
# 2. An explanation of why your request *failed*
#
# <figure>
#  <a href="https://www.earthdatascience.org/images/courses/earth-analytics/apis/consume-rest-basic-anatomy-mulesoft.png">
#  <img src="https://www.earthdatascience.org/images/courses/earth-analytics/apis/consume-rest-basic-anatomy-mulesoft.png" alt="RESTful response vs request."></a>
#     <figcaption>First, you create a request that queries the data repository for some data using the API. The repository gets the request and in turn processes it. Finally, it responds. If your request was a good one, the response will include the data that you are interested in. <a href="https://docs.mulesoft.com/mule-user-guide/v/3.7/consuming-a-rest-api" target="_blank">Image Source</a>
#     </figcaption>
# </figure>
#
# ### API Endpoints
#
# When we talk about an endpoint, we are referring to a datasource available
# through an API. These data may be census data, geospatial base maps, water quality or any type of data that has been made available through the API.
#
# ### RESTful Web APIs
#
# There are many different types of web APIs. One of the most common types is
# a `REST`, or `REST`ful, API. A *RESTful* API is a web API that uses
# URL arguments to specify what information you want returned through the API.
#
# To put this all into perspective, next, you will explore a RESTful API interface example. We will look at GIS data from the [California Open Data Portal](https://data.ca.gov/). Specifically, we will look at some of the geospatial data shared at this website for the 2025 Los Angeles Firestorm event (https://data.ca.gov/group/fire).

# %%
### Packages we must install
! pip install -U leafmap
! pip install folium matplotlib mapclassify
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.7/518.7 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 64.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.5/765.5 kB 33.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 1.3 MB/s eta 0:00:00
# ...

# %%
### Packages we will be using
import requests
import zipfile
import io
import os
from pathlib import Path
import geopandas as gpd
import leafmap
from shapely.geometry import shape

# %%
### Example query
eaton_fire = requests.get("https://gis.data.cnra.ca.gov/api/download/v1/items/6254ba9f9c4f4b0f886f24c902c8eda3/geojson?layers=0")

# %%
### API query response
eaton_fire.json()
# Out:
# {'type': 'FeatureCollection',
#  'name': 'DINS_2025_Eaton_Public_View',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 1,
#     'GLOBALID': 'da82e80c-ada4-4e58-9a42-07b20e48b868',
#     'DAMAGE': 'No Damage',
#     'STRUCTURETYPE': 'Single Family Residence Multi Story'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.097536527668, 34.1749786071185]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 2,
#     'GLOBALID': 'a6839b8e-157a-41fb-8aab-b35095b1e4ea',
#     'DAMAGE': 'No Damage',
#     'STRUCTURETYPE': 'Single Family Residence Multi Story'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.113341637694, 34.185655782766]}},
#   {'type': 'Feature',
#    'properties': {'OBJECTID': 3,
#     'GLOBALID': '1fe4c4eb-8f02-4251-8487-1aaa27e14d25',
#     'DAMAGE': 'Affected (1-9%)',
# ...

# %%
eaton_fire.json().keys()
# Out:
# dict_keys(['type', 'name', 'crs', 'features'])

# %%
eaton_fire.json()['features']

# %%
### Create a list to store the processed data. --> processing list of dictionaries
data_list = []
geometries = []

### Extract and process each feature
for feature in eaton_fire.json()['features']:
    # Extract properties
    props = feature['properties']
    # Extract and convert geometry
    geom = shape(feature['geometry'])
    # Add properties to data list
    data_list.append(props)
    # Add geometry to geometries list
    geometries.append(geom)

### Create a pandas DataFrame first
eaton_df = pd.DataFrame(data_list)

eaton_df.head()
# Out:
#    OBJECTID                              GLOBALID           DAMAGE  \
# 0         1  da82e80c-ada4-4e58-9a42-07b20e48b868        No Damage
# 1         2  a6839b8e-157a-41fb-8aab-b35095b1e4ea        No Damage
# 2         3  1fe4c4eb-8f02-4251-8487-1aaa27e14d25  Affected (1-9%)
# 3         4  db9534b1-cb22-4bef-a29d-1595d191c443        No Damage
# 4         5  f76e2296-7507-4684-8231-68d501ef4fb1        No Damage
#
#                           STRUCTURETYPE
# 0   Single Family Residence Multi Story
# 1   Single Family Residence Multi Story
# 2  Single Family Residence Single Story
# 3                Utility Misc Structure
# 4  Single Family Residence Single Story

# %%
### Create the GeoDataFrame using the pandas DF as a starting point
eaton_spatial = gpd.GeoDataFrame(
    eaton_df,
    geometry=geometries,
    crs="EPSG:4326"  # WGS84 coordinate system
)

# %%
### Get a high level overview of the spatial data
eaton_spatial.head()
# Out:
#    OBJECTID                              GLOBALID           DAMAGE  \
# 0         1  da82e80c-ada4-4e58-9a42-07b20e48b868        No Damage
# 1         2  a6839b8e-157a-41fb-8aab-b35095b1e4ea        No Damage
# 2         3  1fe4c4eb-8f02-4251-8487-1aaa27e14d25  Affected (1-9%)
# 3         4  db9534b1-cb22-4bef-a29d-1595d191c443        No Damage
# 4         5  f76e2296-7507-4684-8231-68d501ef4fb1        No Damage
#
#                           STRUCTURETYPE                     geometry
# 0   Single Family Residence Multi Story  POINT (-118.09754 34.17498)
# 1   Single Family Residence Multi Story  POINT (-118.11334 34.18566)
# 2  Single Family Residence Single Story   POINT (-118.11356 34.1857)
# 3                Utility Misc Structure  POINT (-118.09772 34.17498)
# 4  Single Family Residence Single Story  POINT (-118.09749 34.17506)

# %%
### Interactively visualize the data
eaton_spatial.loc[:1000].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Using packages to query data for us
#
# The focus of the rest of this tutorial will shift to packages that developers have created in the Python ecosystem. These packages perform that `requests.get` workflow for us, or any other API-based authentication and querying.
#
# We will start by looking at eBird data that are shared at [GBIF](https://www.gbif.org). Specifically, the [eBird Observation Dataset](https://www.gbif.org/dataset/4fa7b334-ce0d-4e88-aaae-2e0c138d049e#registration) have enriched the GBIF platform with over 1.5 billion (!) observations of birds around the world.

# %%
! pip install pygbif
! pip install pyalex

# %%
### Functions that one can use from the PyGBIF package
from pygbif import species as species
from pygbif import occurrences as occ
from pygbif import maps

# %%
### One can pass a list of species using their Latin binomials
### and obtain their numeric ID to be able to query various data
### from GBIF about these species
splist = ['Cyanocitta stelleri', 'Junco hyemalis', 'Callipepla californica', 'Vireo bellii', 'Toxostoma redivivum']
keys = [ species.name_backbone(x)['usageKey'] for x in splist ]

# %%
keys
# Out:
# [2482598, 9362842, 5228080, 2487441, 5231713]

# %%
### GBIF provides a set of helpful functions, including a mapping functionality
out = maps.map(taxonKey = keys[0], srs='EPSG:4326', z=1) # FMI: https://pygbif.readthedocs.io/en/latest/modules/maps.html
# Display the map
out.plot()

# %% [markdown]
# **Note**: You could directly work with the much richer data from eBird, but that would require you to sign up for a (free) eBird account and click "Request access" next to the **eBird API** dataset row to get an "API key", or essentially a unique password that authenticates your request to the eBird servers. [You can access the eBird Data Access request platform here](https://ebird.org/data/download).
#
# You could use these eBird data to perform really fascinating analyses. This recent [GBIF, Google Earth Engine, and eBird](https://data-blog.gbif.org/post/2025-01-23-time-series-of-land-surface-temperature/) tutorial shows how one could look at relationships between temperature and occurrence data for a songbird species in North America.
#
# That same website also provides a nice [friendly beginners' guide to the GBIF API](https://data-blog.gbif.org/post/gbif-api-beginners-guide/).

# %%
### URL of the eBird sample data - not queried via the authenticated API
url = "https://ebird.org/downloads/samples/ebd-datafile-SAMPLE.zip"

### Download the zip file
response = requests.get(url)

# %%
### Check that the download worked - should yield a status code of 200
response.status_code
# Out:
# 200

# %%
### Create a directory to store the unzipped objects
ebird_dir = "/content/ebird"
os.makedirs(ebird_dir, exist_ok=True)

# %%
### Unzip the downloaded object
with zipfile.ZipFile(io.BytesIO(response.content)) as zip_file:
  # Extract all of the files to the ebird_dir
  zip_file.extractall(ebird_dir)

# %%
# Find all files with .csv or .txt extensions recursively
file_paths = list(Path(ebird_dir).rglob("*.csv")) + list(Path(ebird_dir).rglob("*.txt"))

# Print the file paths
print("Found files:")
for path in file_paths:
    print(path)
# Out:
# Found files:
# /content/ebird/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/USFWSCodes.txt
# /content/ebird/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/terms_of_use.txt
# /content/ebird/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/recommended_citation.txt
# /content/ebird/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/BCRCodes.txt
# /content/ebird/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/ebd_US-AL-101_202204_202204_relApr-2022.txt
# /content/ebird/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/IBACodes.txt
# /content/ebird/__MACOSX/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/._USFWSCodes.txt
# /content/ebird/__MACOSX/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/._ebd_US-AL-101_202204_202204_relApr-2022.txt
# /content/ebird/__MACOSX/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/._BCRCodes.txt
# /content/ebird/__MACOSX/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/._terms_of_use.txt
# ...

# %%
file_paths[4]
# Out:
# PosixPath('/content/ebird/ebd_US-AL-101_202204_202204_relApr-2022_SAMPLE/ebd_US-AL-101_202204_202204_relApr-2022.txt')

# %%
### Display a subset of the data you could receive from
### querying the eBird API (requires an API key)
ebird_df = pd.read_csv(file_paths[4], sep="\t")
ebird_df.head()
# Out:
#                           GLOBAL UNIQUE IDENTIFIER  \
# 0  URN:CornellLabOfOrnithology:EBIRD:OBS1408495335
# 1  URN:CornellLabOfOrnithology:EBIRD:OBS1406077901
# 2  URN:CornellLabOfOrnithology:EBIRD:OBS1401854254
# 3  URN:CornellLabOfOrnithology:EBIRD:OBS1414367166
# 4  URN:CornellLabOfOrnithology:EBIRD:OBS1395326171
#
#              LAST EDITED DATE  TAXONOMIC ORDER CATEGORY  TAXON CONCEPT ID  \
# 0  2022-04-29 18:30:39.479487            20762  species  avibase-9E9F2476
# 1  2022-04-27 12:30:42.055848            20762  species  avibase-9E9F2476
# 2  2022-04-23 22:11:46.383377            20762  species  avibase-9E9F2476
# 3  2022-05-04 09:36:46.461973            20762  species  avibase-9E9F2476
# 4  2022-04-17 14:31:51.742159            20762  species  avibase-9E9F2476
#
#      COMMON NAME        SCIENTIFIC NAME SUBSPECIES COMMON NAME  \
# 0  American Crow  Corvus brachyrhynchos                    NaN
# 1  American Crow  Corvus brachyrhynchos                    NaN
# ...

# %% [markdown]
# Now, we will examine how we can query an Open Data platform that gives us clean JSON data for academic publications. [OpenAlex](https://docs.openalex.org) is a nonprofit seeking to provide an academic search engine that offers more features than (paywalled) providers such as Web of Science or Scopus.
#
# Let's get started by importing the package and key functions we will need.

# %%
### Import the PyAlex package and functions
import pyalex
from pyalex import Works, Authors, Sources, Institutions, Topics, Publishers, Funders
from pyalex import config

# %%
### Provide your email address so that you can enter the "polite pool"
### and get much more rapid request delivery
### FMI: https://docs.openalex.org/how-to-use-the-api/rate-limits-and-authentication#the-polite-pool
pyalex.config.email = "isabeldramos02@gmail.com" # replace with your email

# %% [markdown]
# From the PyAlex docs:
#
# > By default, PyAlex will raise an error at the first failure when querying the OpenAlex API. You can set `max_retries` to a number higher than 0 to allow PyAlex to retry when an error occurs. `retry_backoff_factor` is related to the delay between two retry, and `retry_http_codes` are the HTTP error codes that should trigger a retry.

# %%
### Specify some controls for the API querying
### such as how many times you will retry a failed request
config.max_retries = 3
config.retry_backoff_factor = 0.1
config.retry_http_codes = [429, 500, 503]

# %% [markdown]
# The heart of literature reviews, meta-analyses, or any other systematic review typically focuses on studies conducted on a focal topic. We can automate (!!!) this search process using PyAlex's and [OpenAlex's `search` functionality](https://docs.openalex.org/api-entities/works/search-works).

# %%
### Query for studies that include the term "biocultural restoration"
### in the abstract field. By default, this returns only 25 results
results = Works().search_filter(abstract="biocultural restoration").get()

# %%
### Create a data frame to store our results
bioculturalDF = pd.DataFrame.from_dict(results)
bioculturalDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              25 non-null     object
#  1   doi                             25 non-null     object
#  2   title                           25 non-null     object
#  3   display_name                    25 non-null     object
#  4   relevance_score                 25 non-null     float64
#  5   publication_year                25 non-null     int64
#  6   publication_date                25 non-null     object
#  7   ids                             25 non-null     object
#  8   language                        25 non-null     object
#  9   primary_location                25 non-null     object
#  10  type                            25 non-null     object
#  11  type_crossref                   25 non-null     object
# ...

# %%
### Display our results
pd.set_option('display.max_columns',55)
bioculturalDF.head()
# pd.reset_option('display.max_columns') # uncomment to reset to default
# Out:
#                                  id                                 doi  \
# 0  https://openalex.org/W2894575939  https://doi.org/10.3390/su10103554
# 1  https://openalex.org/W2891810977  https://doi.org/10.3390/su10093294
# 2  https://openalex.org/W2910722370  https://doi.org/10.3390/su11010283
# 3  https://openalex.org/W2300558775   https://doi.org/10.1111/rec.12318
# 4  https://openalex.org/W2757090359      https://doi.org/10.2984/71.4.4
#
#                                                title  \
# 0  The Moku System: Managing Biocultural Resource...
# 1  The Social-Ecological Keystone Concept: A Quan...
# 2  Hawai‘i in Focus: Navigating Pathways in Globa...
# 3  Key biocultural values to guide restoration ac...
# 4  I Ka Wā Ma Mua: The Value of a Historical Ecol...
#
#                                         display_name  relevance_score  \
# 0  The Moku System: Managing Biocultural Resource...        550.27875
# ...

# %% [markdown]
# ### Cursors and paging
#
# When working with APIs, especially those that return large datasets, paging and cursors are common techniques used to manage and retrieve data in smaller, manageable chunks.
#
# #### What is Paging?
#
# Paging refers to splitting a large dataset into smaller "pages" of results. Instead of returning all results at once, the API returns a subset (e.g., 100 items per page). You can request subsequent pages by specifying a page number or using a next token.
#
# #### What is a Cursor?
#
# A cursor is a pointer or token that keeps track of your position in the dataset. It allows you to fetch the next set of results without manually tracking page numbers. Cursors are often used in APIs to handle large datasets efficiently and ensure consistency, even if the data changes between requests.
#
# #### Why Use Paging and Cursors?
#
# * Performance: Fetching smaller chunks of data reduces memory usage and improves response times.
# * Scalability: Prevents overloading the server or client with too much data at once.
# * Consistency: Cursors ensure that you don't miss or duplicate records, even if the dataset changes during pagination.
#
# **Common API Patterns**:
#
# * Page-Based Pagination: Request specific pages using a page parameter (e.g., `?page=2`).
#   + Often includes metadata like `total_pages` and `current_page`.
# * Cursor-Based Pagination: Use a cursor or next_token to fetch the next set of results. The API provides a `next_cursor` or `next_page_token` in the response to continue pagination.
# * Limit and Offset: Specify a limit (number of items per page) and offset (starting point).
#   + Example: `?limit=50&offset=100 retrieves items 101–150.`
#
# In the example of our initial biocultural restoration query, we may be curious to see if we can get a larger sample of literature. Let's see how we can use cursors and pagination to achieve that.

# %%
### Initialize a pager
pager = Works().search_filter(abstract="biocultural restoration").paginate(method="page",per_page=25, n_max=100) # keep this small and toy, n_max=100

# %%
### Collect all results
all_results = []
for page in pager:
  all_results.extend(page) # Concatenate to the initially empty list (then add to existing list) of studies from the current page (e.g. 0-25, 26-50, 51-75, etc.)

# %%
### Convert this set of results to a larger pandas DataFrame
biocultural_big = pd.DataFrame(all_results)

# %%
### Inspect our data
biocultural_big.head()
# Out:
#                                  id                                 doi  \
# 0  https://openalex.org/W2894575939  https://doi.org/10.3390/su10103554
# 1  https://openalex.org/W2891810977  https://doi.org/10.3390/su10093294
# 2  https://openalex.org/W2910722370  https://doi.org/10.3390/su11010283
# 3  https://openalex.org/W2300558775   https://doi.org/10.1111/rec.12318
# 4  https://openalex.org/W2757090359      https://doi.org/10.2984/71.4.4
#
#                                                title  \
# 0  The Moku System: Managing Biocultural Resource...
# 1  The Social-Ecological Keystone Concept: A Quan...
# 2  Hawai‘i in Focus: Navigating Pathways in Globa...
# 3  Key biocultural values to guide restoration ac...
# 4  I Ka Wā Ma Mua: The Value of a Historical Ecol...
#
#                                         display_name  relevance_score  \
# 0  The Moku System: Managing Biocultural Resource...        550.27875
# ...

# %%
### Inspect our data
biocultural_big.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              100 non-null    object
#  1   doi                             95 non-null     object
#  2   title                           100 non-null    object
#  3   display_name                    100 non-null    object
#  4   relevance_score                 100 non-null    float64
#  5   publication_year                100 non-null    int64
#  6   publication_date                100 non-null    object
#  7   ids                             100 non-null    object
#  8   language                        100 non-null    object
#  9   primary_location                100 non-null    object
#  10  type                            100 non-null    object
#  11  type_crossref                   100 non-null    object
# ...
